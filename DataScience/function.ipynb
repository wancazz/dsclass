# %% [markdown]
# Function

# %%
def my_function():
    print("Hello from a function")

# %%
my_function()
# Out:
# Hello from a function

# %%
def my_function(name):
    print(name + "! Hello from a function")

# %%
my_function("Sarah")
# Out:
# Sarah! Hello from a function

# %%
def nameAge(name,age):
    print("Hi, I am " + name)
    print("My age is " + str(age))

# %%
nameAge("Suraj",27) #positional argument, the order of the argument matters
# Out:
# Hi, I am Suraj
# My age is 27

# %%
nameAge(age=27, name="Suraj") #no need to follow order because we are using keywords argument, so the position does not matter
# Out:
# Hi, I am Suraj
# My age is 27

# %%
def nameAge(name,age=27):
    print("Hi, I am " + name)
    print("My age is " + str(age))

# %%
nameAge("Suraj",20)
# Out:
# Hi, I am Suraj
# My age is 20

# %%
def get_formatted_name(first_name,last_name):
    """Return a full name, neatly formatted."""
    full_name=first_name + ' ' + last_name
    return full_name.title()

# %%
musician = get_formatted_name('jimi','hendrix')

# %%
musician
# Out:
# 'Jimi Hendrix'

# %%
def square_value(num):
    "This function returns the square value of the entered number"
    return num**2

# %%
print(square_value(2))
print(square_value(-4))
# Out:
# 4
# 16

# %%
def get_formatted_name(first_name,last_name,middle_name=''):
    """Return a full name, neatly formatted."""
    full_name=first_name + ' ' + middle_name + ' ' + last_name
    return full_name.title()

# %%
musician3 = get_formatted_name('hassan','ali')
musician3
# Out:
# 'Hassan  Ali'

# %%
musician4 = get_formatted_name('hassan','ali','mohd')
print(musician4)
# Out:
# Hassan Mohd Ali

# %%
def build_person(first_name,last_name):
    """Return a dictionary of information about a person."""
    person = {'first':first_name,'last':last_name}
    return person

# %%
musician = build_person('jimi','hendrix')
print(musician)
# Out:
# {'first': 'jimi', 'last': 'hendrix'}

# %%
def my_function(food):
    for x in food:
        print(x)

# %%
fruits = ["apple","banana",'cherry']
my_function(fruits)
# Out:
# apple
# banana
# cherry

# %%
vegetables = ["spinach","carrot","cauliflower","tomato"]
my_function(vegetables)
# Out:
# spinach
# carrot
# cauliflower
# tomato

# %%
meats = ["chicken","fish","lamb"]
my_function(meats)
# Out:
# chicken
# fish
# lamb

# %%
def make_pizza(*toppings):
    """Print the list of toppings that have been requested."""
    print(toppings)

# %%
make_pizza('pepperoni')
# Out:
# ('pepperoni',)

# %%
make_pizza('mushrooms','green peppers','extra cheese')
# Out:
# ('mushrooms', 'green peppers', 'extra cheese')

# %%
def make_pizza(size, *toppings): #the arbitrary argument must be placed last and only one arbitrary number of arguments can be used
    """Summarise the pizza we are about to make."""
    print("\nMaking a " + str(size) + "-inch pizza with the following toppings:")
    for topping in toppings:
        print("- " + topping)

# %%
make_pizza(16,'pepperoni')
# Out:
# Making a 16-inch pizza with the following toppings:
# - pepperoni

# %%
make_pizza(12, 'mushrooms','green peppers','extra cheese')
# Out:
# Making a 12-inch pizza with the following toppings:
# - mushrooms
# - green peppers
# - extra cheese

# %%
def build_profile(first,last,**user_info):
    """Build a dictionary containing everything we know about a user"""
    profile = {}
    profile['first_name'] = first
    profile['last_name'] = last
    for key,value  in user_info.items():
        profile[key] = value
    return profile

# %%
user_profile = build_profile('albert','einstein',location='princeton',field='physics')
print(user_profile)
# Out:
# {'first_name': 'albert', 'last_name': 'einstein', 'location': 'princeton', 'field': 'physics'}
