# %% [markdown]
# Dictionary

# %%
alien_0 = {'color':'green','point':5}
print(alien_0)
# Out:
# {'color': 'green', 'point': 5}

# %%
print(alien_0['color'])
print(alien_0['point'])
# Out:
# green
# 5

# %%
alien_0['x_position'] = 0
alien_0['y_position'] = 25
print(alien_0)
# Out:
# {'color': 'green', 'point': 5, 'x_position': 0, 'y_position': 25}

# %%
alien_0['color'] = 'yellow'
print(alien_0)
print("The alien is now " + alien_0['color'] + ".")
# Out:
# {'color': 'yellow', 'point': 5, 'x_position': 0, 'y_position': 25}
# The alien is now yellow.

# %%
del alien_0['point']
print(alien_0)
# Out:
# {'color': 'yellow', 'x_position': 0, 'y_position': 25}

# %%
motorcycles = ['honda','yamaha','suzuki']

# %%
for motor in motorcycles:
    print('I like ' + motor)
# Out:
# I like honda
# I like yamaha
# I like suzuki

# %%
customer = {'Name':'John','Status': 'Married', 'Hometown': 'Kuala Lumpur'}

for key, value in customer.items():
    print("\nKey: " + key)
    print("Value: " + value)
# Out:
# Key: Name
# Value: John
#
# Key: Status
# Value: Married
#
# Key: Hometown
# Value: Kuala Lumpur

# %%
student = {'Syazwan': 'A123', 'Azman': 'B124', 'Ali':'C125'}

for name, ID in student.items():
    print(name + " is a UKM student with ID number " + ID)
# Out:
# Syazwan is a UKM student with ID number A123
# Azman is a UKM student with ID number B124
# Ali is a UKM student with ID number C125

# %%
ages = {'Ali': 6, 'Wong': 8, 'Ren': 4} #age number is integer here

for name, age in ages.items():
        print(name + " is " + str(age) + " years old.")
# Out:
# Ali is 6 years old.
# Wong is 8 years old.
# Ren is 4 years old.

# %%
print("\nThe Following information are required: ")

for info in customer.keys():
    print(info.title())
# Out:
# The Following information are required:
# Name
# Status
# Hometown

# %%
print("\nThe Following information are required: ")

for info in sorted(customer.keys()):
    print(info.title() + " is compulsory. ")
# Out:
# The Following information are required:
# Hometown is compulsory.
# Name is compulsory.
# Status is compulsory.

# %%
print("The details of a customer are listed below:\n")

for info in customer.values():
    print(info.title())
# Out:
# The details of a customer are listed below:
#
# John
# Married
# Kuala Lumpur

# %%
people1 = {'name': 'John', 'age': '27', 'sex': 'Male'}
people2 = {'name': 'Marie', 'age': '22', 'sex': 'Female'}
people3 = {'name': 'Luna', 'age': '24', 'sex': 'Female', 'married': 'No'}
people4 = {'name': 'Peter', 'age': '29', 'sex': 'Male', 'married': 'Yes'}

# %%
peoples = [people1, people2, people3, people4]

for people in peoples:
    print(people)
# Out:
# {'name': 'John', 'age': '27', 'sex': 'Male'}
# {'name': 'Marie', 'age': '22', 'sex': 'Female'}
# {'name': 'Luna', 'age': '24', 'sex': 'Female', 'married': 'No'}
# {'name': 'Peter', 'age': '29', 'sex': 'Male', 'married': 'Yes'}

# %%
peoples = {'John': ['27 years old', 'Male'],
'Marie': ['22 years old', 'Female'],
'Luna': ['24 years old', 'Female','Not married'],
'Peter': ['29 years old', 'Male','Married']}

# %%
for name, info in peoples.items():
    print("\n" + name.title() + " detail's are:")
    for value in info:
        print(value)
# Out:
# John detail's are:
# 27 years old
# Male
#
# Marie detail's are:
# 22 years old
# Female
#
# Luna detail's are:
# 24 years old
# Female
# Not married
#
# Peter detail's are:
# 29 years old
# Male
# Married

# %%
pc = {'Dell': ['64gb', 'RM1000'],
'Acer': ['32gb', 'RM500','iGPU'],
'HP': ['128gb', 'RM1500'],
'Xiaomi': ['256gb', 'RM3000','Dedicated GPU']}

# %%
for brand, info in pc.items():
    print("\n" + brand + " is good")
    for specs in info:
        print(specs)
# Out:
# Dell is good
# 64gb
# RM1000
#
# Acer is good
# 32gb
# RM500
# iGPU
#
# HP is good
# 128gb
# RM1500
#
# Xiaomi is good
# 256gb
# RM3000
# Dedicated GPU

# %%
people = {'Albert': {'age': '27',
'sex': 'Male'},
'Einstein':{'age': '22',
'sex': 'Female'},'Abu': {'age': '40', 'sex': 'female', 'edu': 'Master'}
}

# %%
for name, info in people.items():
    print("\n" + name + " info's are:")
    print("Age: " + info['age'] + " years old")
    print("Sex: " + info['sex'])
# Out:
# Albert info's are:
# Age: 27 years old
# Sex: Male
#
# Einstein info's are:
# Age: 22 years old
# Sex: Female
#
# Abu info's are:
# Age: 40 years old
# Sex: female

# %%
pc1 = {'Dell': { 'Storage':'64gb', 'Price':'RM1000'},
'Acer': { 'Storage':'32gb', 'Price':'RM500', 'Graphics':'iGPU'},
'HP': { 'Storage':'128gb', 'Price':'RM1500'},
'Xiaomi': { 'Storage':'256gb', 'Price':'RM3000', 'Graphics':'Dedicated GPU'}
}

print(pc1)
# Out:
# {'Dell': {'Storage': '64gb', 'Price': 'RM1000'}, 'Acer': {'Storage': '32gb', 'Price': 'RM500', 'Graphics': 'iGPU'}, 'HP': {'Storage': '128gb', 'Price': 'RM1500'}, 'Xiaomi': {'Storage': '256gb', 'Price': 'RM3000', 'Graphics': 'Dedicated GPU'}}

# %%
print("My name is Syazwan")
# Out:
# My name is Syazwan

# %%
input("My name is ")
print(name)
# Out:
# Syazwan

# %%
name = input("My name is ")
print(name)
# Out:
# Syazwan

# %%
name = input("Please enter your name: ")
print("Hello, " + name + "!")
# Out:
# Hello, Wan!

# %%
age = input("How old are you? ")
print("You're " + age + " years old!")
age = int(age)
age >= 18
# Out:
# You're 23 years old!
# True

# %%
i = 1
while i <= 5:
    print(i)
    i+= 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
i = 1
while i < 6:
    print(i)
    if (i == 3):
        break
    i += 1
# Out:
# 1
# 2
# 3

# %%
i = 0
while i < 6:
    i += 1
    if i == 3:
        continue
    print(i)
# Out:
# 1
# 2
# 4
# 5
# 6

# %%
prompt = "\nPlease enter the name of a city you have visited:"
prompt += "\n(Enter 'quit' when you are finished.) "

while True:
    city = input(prompt)
    if city == 'quit':
        break
    else:
        print("I'd love to go to " + city.title() + "!")
# Out:
# I'd love to go to Kl!
# I'd love to go to Kb!
# I'd love to go to Kk!
# I'd love to go to Bangi!

# %%
prompt = "\nPlease enter the name of a city you have visited:"
prompt += "\n(Enter 'quit' when you are finished.) "

Active = True
while Active:
    city = input(prompt)
    if city == 'quit':
        Active = False
    else:
        print("I'd love to go to " + city.title() + "!")
# Out:
# I'd love to go to Kk!
# I'd love to go to Labuan!
# I'd love to go to Bbb!

# %%
name = input("My name is ")
print(name)
# Out:
# te
