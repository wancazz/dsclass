# %%
A = "Al-Ghazali"
B = "Ibn Battuta"
C = "Carl Jung"

# %%
guests = [A, B, C]

# %%
guests
# Out:
# ['Al-Ghazali', 'Ibn Battuta', 'Carl Jung']

# %%
for guest in guests:
    print("Dear " + guest + ", you are invited to dinner.")
# Out:
# Dear Al-Ghazali, you are invited to dinner.
# Dear Ibn Battuta, you are invited to dinner.
# Dear Carl Jung, you are invited to dinner.

# %%
print("Unfortunately " + A + " cannot come to dinner")
# Out:
# Unfortunately Al-Ghazali cannot come to dinner

# %%
guests[0] = "Daniel Kahneman"

# %%
guests
# Out:
# ['Daniel Kahneman', 'Ibn Battuta', 'Carl Jung']

# %%
for guest in guests:
    print("Dear " + guest + ", you are invited to dinner.")
# Out:
# Dear Daniel Kahneman, you are invited to dinner.
# Dear Ibn Battuta, you are invited to dinner.
# Dear Carl Jung, you are invited to dinner.

# %%
animals = ["Cockroach", "Grasshopper", "Cricket"]

# %%
for animal in animals:
    print(animal)
# Out:
# Cockroach
# Grasshopper
# Cricket

# %%
for animal in animals:
    print(animal + " can jump and move quickly.\n")
# Out:
# Cockroach can jump and move quickly.
#
# Grasshopper can jump and move quickly.
#
# Cricket can jump and move quickly.

# %%
print("All of these animals are insects that can move actively on land.")
# Out:
# All of these animals are insects that can move actively on land.

# %%
age = 25

if age < 2:
    print("The person is a baby.")
elif age < 4:
    print("The person is a toddler.")
elif age < 13:
    print("The person is a kid.")
elif age < 20:
    print("The person is a teenager.")
elif age < 65:
    print("The person is an adult.")
else:
    print("The person is an elder.")
# Out:
# The person is an adult.

# %%
age = int(input("Enter age: "))

if age < 2:
    print("The person is a baby.")
elif age < 4:
    print("The person is a toddler.")
elif age < 13:
    print("The person is a kid.")
elif age < 20:
    print("The person is a teenager.")
elif age < 65:
    print("The person is an adult.")
else:
    print("The person is an elder.")
# Out:
# Enter age:  1
# The person is a baby.
